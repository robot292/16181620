# %%
#-*-coding:utf8-*-
import csv
import matplotlib.pyplot as plt
f = open('한국관광공사_전국_음식점_정보_20160906.csv', encoding = 'cp949')

data = csv.reader(f)
pivot = []

# plt.rc('font', family='applegothic')

name = int(input('1. 지역명으로 찾기 \n2. 시군구명으로 찾기 \n3. 티비,sns 출연 프로그램명으로 찾기 \n4. 음식점명으로 찾기 \n5. 특징으로 찾기 \n6. 특정 값 통계내기\n찾고자 하는 범주를 선택해주십시오.'))

if name == 1 :
    momentoftruth = int(input('선택한게 맞으시다면 1을 입력해주세요'))
        
    if momentoftruth == 1:
        keyword = input('찾고자하는 지역명을 입력해주세요 : ')
        data = csv.reader(f)
        for row in data :
            if keyword in row[4] :
                print(row)
        
if name == 2 :
    momentoftruth = int(input('선택한게 맞으시다면 1을 입력해주세요'))
    
    if momentoftruth == 1:
        keyword = input('찾고자하는 시군구명을 입력해주세요 : ')
        data = csv.reader(f)
        for row in data :
            if keyword in row[5] :
                print(row)   
        
if name == 3 :
    momentoftruth = int(input('선택한게 맞으시다면 1을 입력해주세요'))
    
    if momentoftruth == 1:
        keyword = input('찾고자하는 티비, sns 출연 프로그램명을 입력해주세요 : ')
        data = csv.reader(f)
        for row in data :
            if keyword in row[6] :
                print(row)        
    
        
if name == 4 :
    momentoftruth = int(input('선택한게 맞으시다면 1을 입력해주세요'))
    
    if momentoftruth == 1:
        keyword = input('찾고자하는 음식점명을 입력해주세요 : ')
        data = csv.reader(f)
        for row in data :
            if keyword in row[0] :
                print(row)       
    
        
if name == 5 :
    momentoftruth = int(input('선택한게 맞으시다면 1을 입력해주세요'))
    
    if momentoftruth == 1:
        keyword = input('찾고자하는 단어를 입력해주세요 : ')
        data = csv.reader(f)
        for row in data :
            if keyword in row[6] :
                print(row)
        
if name == 6 :
    keyword = input('통계를 내고자 하는 종류\n(1. 음식의 종류 2.위치한 지역 3.음식점이 위치한 시군구명)\n를 선택하여 주십시오 : ')
    
    if keyword == '1' :
        for row in data:
            if row[3] in result:
                result[row[3]]+=1
            else:
                result[row[3]]=1
    print(result)
            
    if keyword == '2' :
        for row in data:
            a=row[4]
            num=(a.split(',')[0])
            if row[4] in result:
                result[row[4]]+=1
            else:
                result[row[4]]=1
    print(result)
            
    if keyword == '3' :
        for row in data:
            if row[5] in result:
                result[row[5]]+=1
            else:
                result[row[5]]=1
                
        
    print(result)
# Out:
# 1. 지역명으로 찾기
# 2. 시군구명으로 찾기
# 3. 티비,sns 출연 프로그램명으로 찾기
# 4. 음식점명으로 찾기
# 5. 특징으로 찾기
# 6. 특정 값 통계내기
# 찾고자 하는 범주를 선택해주십시오.5
# 선택한게 맞으시다면 1을 입력해주세요1
# 찾고자하는 단어를 입력해주세요 : 비빔밥
# ['고궁(본점)', '음식', '음식점', '한식', '전라북도', '전주시', "골동반'이란 여러 가지 귀한 것들이 갖추어져 있다는 뜻으로 옛날 임금님 수라에 오른 비빔밥을 골동반이라 하였는데, 고궁의 골동반은 이러한 궁중의 비빔밥을 현대 감각에 맞도록 맛을 살려 재현한 것으로 그 상차림을 보면 해물신선로, 모주, 전주식육회, 모듬전, 갈비떡찜, 삼합, 북어구이, 황포묵무침, 수삼샐러드, 잡채 등 실로 대단하다 할 수 있다. 해마다 관광안내지도에 빠지지 않고 지명되는 업소인 만큼 전주에 방문 한다면 꼭 한 번 들러봐야할 명소 중에 명소다."]
# ['진상', '음식', '음식점', '한식', '경상남도', '창원시', "진상은 향토음식 전문점으로 세계음식박람회에서 금상을 수상한 '해초비빔밥'을 맛볼  수 있는 곳이다. 해조류 가루를 빻아 섞어 지어낸 밥에 해조류와 새우, 연어알 등을 넣고 해조류 소스와 함께 비벼 먹는 그 맛이 일품이다. "]
# ['무쇠가마솥곰탕', '음식', '음식점', '한식', '울산', '울주군', '신불산 온천단지 내에 위치하고 있으며 곰탕전문점으로 곰탕외에도 김치찌개, 비빔밥 등 메뉴가 있다.']
# ['석촌', '음식', '음식점', '한식', '서울', '송파구', ' 롯데월드 쇼핑몰 3층 민속박물관의 조선시대 장터 풍경을 그대로 재현한 저자거리에 위치하고 있는 석촌은 한정식과 돌솥비빔밥, 민속주 등을 주메뉴로 한다. ']
# ...

# %% [markdown]
# # 다시 처음으로 돌아가는것
# 줄 전체를 print
# 문장속에서 특정 찾고 표시하기

# %%
name = input('1. 지역명으로 찾기 \n 2. 시군구명으로 찾기 \n 3. 티비,sns 출연 프로그램명으로 찾기 \n 4. 음식점명으로 찾기 \n 5. 특징으로 찾기 \n 찾고자 하는 범주를 선택해주십시오.')

# %%
if name ==1 :
    momentoftruth = int(input('선택한게 맞으시다면 1\n메뉴로 돌아가고 싶으시다면 0을 입력해주세요'))
    
    if momentoftruth == 1:
        print()
        
    if momentoftruth == 0 :

# %%
#-*-coding:utf8-*-
import csv
f = open('한국관광공사_전국_음식점_정보_20160906.csv')

data = csv.reader(f)
pivot = []

name = int(input('1. 지역명으로 찾기 \n2. 시군구명으로 찾기 \n3. 티비,sns 출연 프로그램명으로 찾기 \n4. 음식점명으로 찾기 \n5. 특징으로 찾기 \n찾고자 하는 범주를 선택해주십시오.'))

if name == 1 :
    momentoftruth = int(input('선택한게 맞으시다면 1\n메뉴로 돌아가고 싶으시다면 0을 입력해주세요'))
    
    if momentoftruth == 1:
        first = input('원하시는 지역명을 입력하여 주십시오 : ')
        
    #if momentoftruth == 0 :
        
if name == 2 :
    momentoftruth = int(input('선택한게 맞으시다면 1\n메뉴로 돌아가고 싶으시다면 0을 입력해주세요'))
    
    if momentoftruth == 1:
        first = input('원하시는 시군구명을 입력하여 주십시오 : ')
        
    #if momentoftruth == 0 :
        
if name == 3 :
    momentoftruth = int(input('선택한게 맞으시다면 1\n메뉴로 돌아가고 싶으시다면 0을 입력해주세요'))
    
    if momentoftruth == 1:
        first = input('원하시는 티비,sns등 매개체를 입력하여 주십시오 : ')
        
    #if momentoftruth == 0 :
        
if name == 4 :
    momentoftruth = int(input('선택한게 맞으시다면 1\n메뉴로 돌아가고 싶으시다면 0을 입력해주세요'))
    
    if momentoftruth == 1:
        first = input('원하시는 음식점명을 입력하여 주십시오 : ')
        
    #if momentoftruth == 0 :
        
if name == 5 :
    momentoftruth = int(input('선택한게 맞으시다면 1\n메뉴로 돌아가고 싶으시다면 0을 입력해주세요'))
    
    if momentoftruth == 1:
        first = input('원하시는 특징을 입력하여 주십시오 : ')
        
    #if momentoftruth == 0 :

# %%
import csv
f = open('한국관광공사_전국_음식점_정보_20160906.csv', encoding = 'cp949')
keyword = input('찾고자하는 단어를 입력해주세요 : ')
data = csv.reader(f)
for row in data :
    if keyword in row[6] :
        print(row)
# Out:
# 찾고자하는 단어를 입력해주세요 : 비빔밥
# ['고궁(본점)', '음식', '음식점', '한식', '전라북도', '전주시', "골동반'이란 여러 가지 귀한 것들이 갖추어져 있다는 뜻으로 옛날 임금님 수라에 오른 비빔밥을 골동반이라 하였는데, 고궁의 골동반은 이러한 궁중의 비빔밥을 현대 감각에 맞도록 맛을 살려 재현한 것으로 그 상차림을 보면 해물신선로, 모주, 전주식육회, 모듬전, 갈비떡찜, 삼합, 북어구이, 황포묵무침, 수삼샐러드, 잡채 등 실로 대단하다 할 수 있다. 해마다 관광안내지도에 빠지지 않고 지명되는 업소인 만큼 전주에 방문 한다면 꼭 한 번 들러봐야할 명소 중에 명소다."]
# ['진상', '음식', '음식점', '한식', '경상남도', '창원시', "진상은 향토음식 전문점으로 세계음식박람회에서 금상을 수상한 '해초비빔밥'을 맛볼  수 있는 곳이다. 해조류 가루를 빻아 섞어 지어낸 밥에 해조류와 새우, 연어알 등을 넣고 해조류 소스와 함께 비벼 먹는 그 맛이 일품이다. "]
# ['무쇠가마솥곰탕', '음식', '음식점', '한식', '울산', '울주군', '신불산 온천단지 내에 위치하고 있으며 곰탕전문점으로 곰탕외에도 김치찌개, 비빔밥 등 메뉴가 있다.']
# ['석촌', '음식', '음식점', '한식', '서울', '송파구', ' 롯데월드 쇼핑몰 3층 민속박물관의 조선시대 장터 풍경을 그대로 재현한 저자거리에 위치하고 있는 석촌은 한정식과 돌솥비빔밥, 민속주 등을 주메뉴로 한다. ']
# ...
